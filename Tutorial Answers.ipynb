# %% [markdown]
# # Tutorial Answers

# %%
from PIL import Image
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# Assign the following variables in python (use variable names ‘a’,’b’,’c’,’d’). Which data types are produced? (check with 'type')”

# %%
a=1
b=2.0
c='Exeter'
d='3.0'
print (type(a),type(b),type(c),type(d))
# Out:
# <class 'int'> <class 'float'> <class 'str'> <class 'str'>

# %% [markdown]
# Assign a variable: my_string = 'Today we are learning about variables and data-types'. Extract  (using slicing syntax) the following strings from my_string:
#
# 'Today'
# 'data-types'
# 'learning about variables'
# 'sepyt-atad dna selbairav tuoba gninrael era ew yadoT' (backwards!)
# 'yadoT'
# 'Tdyw r erigaotvralsaddt-ye' (?!?)

# %%
my_string = 'Today we are learning about variables and data-types'
print (my_string[:5])
print (my_string[-10:])
print (my_string[13:37])
print (my_string[-1::-1])
print (my_string[4::-1])
print (my_string[::2])
# Out:
# Today
# data-types
# learning about variables
# sepyt-atad dna selbairav tuoba gninrael era ew yadoT
# yadoT
# Tdyw r erigaotvralsaddt-ye

# %% [markdown]
# Create a list with the following values: mylist=[1,2.5,'3','Exeter','Python']. How do you:
# Delete the value 1 from the list (assuming you know which position it is in)
# Delete the value 1 from the list (if you DON'T know which position it is in)
# Reverse the list (think slicing!)
# Add ['Exeter',5,1.2] to the list?
# How many times does 'Exeter' appear in the extended list?

# %%
my_list=[1,2.5,'3','Exeter','Python']
my_list = my_list[1:]
print (my_list)
my_list=[1,2.5,'3','Exeter','Python']
my_list.remove(1)
print(my_list)
my_list=[1,2.5,'3','Exeter','Python']
print (my_list[-1::-1])
my_list = [1,2.5,'3','Exeter','Python'] + ['Exeter',5,1.2]
my_list.count('Exeter')
# Out:
# [2.5, '3', 'Exeter', 'Python']
# [2.5, '3', 'Exeter', 'Python']
# ['Python', 'Exeter', '3', 2.5, 1]
# 2

# %% [markdown]
# Create a dictionary called ‘cities’ with the following index/values: - 1 - 'Exeter', 2 -'Bath',  3 - 'Bristol’, 4 - 'London'.
# Look up the value for the key 3.
# Make a list from the keys of ‘cities’
# Create an integer variable ‘i’ with a value 3
# Look up the value of ‘cities’ in position i.

# %%
cities={1:'Exeter',2:'Bath',3:'London'}
print (cities[3])
print (list(cities.keys()))
i=3
print (cities[i])
# Out:
# London
# [1, 2, 3]
# London

# %% [markdown]
# Create a new python script in VSCode (or another editor of your choice). The function (strictly this is called a ‘method’ as it applies to a string object) ‘split’ takes a string and splits it down into elements (returned as a list) given another string ‘x’ used as a separator. The syntax is my_string.split(x). Assign a variable my_string as in question 2. Use the split command with a space character to generate a list of the individual words in the sentence.
# Assign a new variable containing a list with these words in reverse order.
# Output this variable (using print ())
# Concatenate sentence ‘I’m good at working with ’ with the 3rd word in this list, and output.

# %%
my_string = 'Today we are learning about variables and data-types'
rev_string = my_string.split(' ')[-1::-1]
print (rev_string)
print ("I'm good at working with "+rev_string[2])
# Out:
# ['data-types', 'and', 'variables', 'about', 'learning', 'are', 'we', 'Today']
# I'm good at working with variables

# %% [markdown]
# ‘find’ locates the lowest index of a substring in a string and returns -1 if not found. Optional arguments limit the range of the search, so that s.find('i',10,20) locates the first occurrence of ‘i’ in s between positions 10 and 20 (and  is identical to s[10:20].find('i')). rfind works identically, only returning the highest index of the substring.
# Add to your script from above, find the location of first occurrence of the character ‘w’ in the string.
# Think of 2 different ways of finding the last occurrence of the character ‘w’ in the string.
# Write code to check that your two methods in (2) return the same value.
# Use (1) and one of your methods in (2) to work out if there are one or more occurences of ‘w’ in the string.
# Check this by making a list of the characters in the string, and using the list .count() function/method.

# %%
my_string[my_string.find('w')]
# Out:
# 'w'

# %%
string_pos = my_string[-1::-1].find('w')
#remember python indexes from 0
distance_from_start = string_pos + 1
x = len(my_string)-distance_from_start
my_string[x]
# Out:
# 'w'

# %%
y=my_string.rfind('w')
my_string[y]
# Out:
# 'w'

# %%
x==y
# Out:
# True

# %%
print ("Number of 'w's >1:",x!=y)
# Out:
# Number of 'w's >1: False

# %%
list(my_string).count('w')
# Out:
# 1

# %% [markdown]
# Create a dictionary called ‘number_things’ with the following keys / values ‘text’ -  ‘2’ and  -'numeric' -  3.
# Write a code expression to output the arithmetic sum of the values corresponding to the keys ‘text’ and ‘numeric’
# Write a code expression to concatenate text values of the values corresponding to the keys ‘text’ and ‘numeric’

# %%
number_things={'text':'2','numeric':3}
print (int(number_things['text'])+number_things['numeric'])
print (number_things['text']+str(number_things['numeric']))
# Out:
# 5
# 23

# %%
img=Image.open('accept.png')
img_resized = img.resize((6000, 4000))
plt.imshow(img_resized)

# %%
img=Image.open('accepted.png')
img_resized = img.resize((6000, 4000))
plt.imshow(img_resized)

# %%
img=Image.open('accepted_with_link.png')
img_resized = img.resize((6000, 4000))
plt.imshow(img_resized)

# %% [markdown]
# # Next steps
#
#
# * Go to VS Code, make sure you have the GitHub Expansion Pack installed
# * Click 'Clone GitHub Repository'
# * Use the link to make a LOCAL copy of the assignment repository

# %% [markdown]
# # Make your code edits, Commit Changes, then Push back to GitHub
#
#
# * Go to VS Code, make sure you have the GitHub Expansion Pack installed
# * Click 'Clone GitHub Repository'
# * Use the link to make a LOCAL copy of the assignment repository

# %% [markdown]
# # Seeing Test Results
#
# * Go to GitHub...
# * Select the apppropriate repository
# * Click on the red cross / green tick to see test details
# * Correct errors then commit / push and try again!
